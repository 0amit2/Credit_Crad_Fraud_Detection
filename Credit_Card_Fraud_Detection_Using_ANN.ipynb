# %% [markdown]
# # **Credit_Card_Fraud_Detection_Using_ANN**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import zipfile
zip=zipfile.ZipFile('/content/drive/MyDrive/Data Science/Project/CreditCard.zip')
zip.extractall()
zip.close()

# %%
import keras

np.random.seed(2)

# %%
data=pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# **Pre-Processing**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
data['normalizedAmount']=sc.fit_transform(data['Amount'].values.reshape(-1,1))

# %%
data.drop('Amount',axis=1,inplace=True)

# %%
data.drop('Time',axis=1,inplace=True)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Class  normalizedAmount
# 0  0.128539 -0.189115  0.133558 -0.021053      0          0.244964
# 1  0.167170  0.125895 -0.008983  0.014724      0         -0.342475
# 2 -0.327642 -0.139097 -0.055353 -0.059752      0          1.160686
# 3  0.647376 -0.221929  0.062723  0.061458      0          0.140534
# 4 -0.206010  0.502292  0.219422  0.215153      0         -0.073403
#
# [5 rows x 30 columns]

# %%
X=data.drop('Class',axis=1)

# %%
y=data['Class']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=123)

# %%
X_train
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 99168  -0.866221 -0.919624  2.020857 -1.525794 -1.035785  2.157966 -0.281997
# 69460   0.967267 -0.179598  0.315800  1.354288 -0.273647  0.139429 -0.005874
# 71073  -0.415673  1.080659  0.675844  0.789318  0.158613  0.430765  0.135873
# 275238  2.036473 -0.021870 -1.085398  0.500278 -0.106741 -1.226224  0.187898
# 208891 -4.420316 -3.367604  3.339102  6.050951  2.641524  0.359443 -4.793559
# ...          ...       ...       ...       ...       ...       ...       ...
# 192476  2.085321 -1.119472 -0.260414 -0.829419 -1.373550 -0.504944 -1.224794
# 17730  -1.039001  0.950070  0.389899 -1.217401  1.855856  3.640886 -0.549604
# 28030   1.129333  0.471653  0.657500  2.454111 -0.091741 -0.089917  0.008581
# 277869  1.636784 -0.560857 -1.944589  0.405452  0.157569 -0.635650  0.315338
# 249342  1.906410 -0.531680 -1.175688  0.132728 -0.229802 -0.565090 -0.056376
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 99168   0.608243 -0.595195 -0.192038  ...  0.658829  0.511087  1.154578
# 69460   0.174708  0.195502  0.040867  ... -0.090995 -0.015079 -0.078930
# 71073   0.671417 -1.000854 -0.298512  ... -0.163889  0.287891  0.782205
# 275238 -0.399751  0.320678  0.163216  ... -0.139006  0.159477  0.583649
# 208891 -1.765357 -0.387127  1.087007  ...  0.174084 -1.341109  1.123252
# ...          ...       ...       ...  ...       ...       ...       ...
# 192476  0.027016  0.011921  0.910736  ... -0.011516  0.523933  1.560949
# 17730   1.505694 -0.559184 -0.619047  ...  0.177503 -0.090529 -0.491079
# 28030   0.060009 -0.623285  0.661338  ... -0.212507 -0.048241 -0.201293
# 277869 -0.200477  0.678971 -0.775364  ...  0.276758 -0.100809 -0.465458
# 249342 -0.077301  0.978166 -0.041916  ... -0.156293 -0.109076 -0.261720
#
#              V23       V24       V25       V26       V27       V28  \
# 99168  -0.070794 -1.678518  0.511949  0.159084  0.044666  0.063497
# 69460  -0.131669 -0.001284  0.565061 -0.334174  0.013635  0.017108
# 71073   0.004812 -0.271442 -0.301717 -0.287004 -0.015223 -0.034233
# 275238  0.091193  0.111583  0.003484  0.378828 -0.055797 -0.056548
# 208891 -0.526044  0.180769  0.032032  0.687107  0.850304 -0.142814
# ...          ...       ...       ...       ...       ...       ...
# 192476  0.059730  0.131521 -0.145999  0.012917  0.012268 -0.054809
# 17730  -0.179921  1.004741  0.317712  0.281484  0.153761  0.062423
# 28030   0.053427  0.027638  0.321256 -0.042526  0.001532  0.021002
# 277869 -0.063594 -0.580315 -0.080220 -0.101500 -0.043508 -0.001004
# 249342  0.121635 -0.341628 -0.102660 -0.091871 -0.045385 -0.060711
#
#         normalizedAmount
# 99168           0.562332
# 69460          -0.001598
# 71073          -0.289660
# 275238         -0.285102
# 208891          0.156766
# ...                  ...
# 192476         -0.263312
# 17730          -0.329281
# 28030          -0.305292
# 277869          0.462260
# 249342         -0.096392
#
# [227845 rows x 29 columns]

# %%
X_train.shape
# Out:
# (227845, 29)

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)
y_train=np.array(y_train)
y_test=np.array(y_test)

# %% [markdown]
# # Deep Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout

# %%
model=Sequential([
    Dense(16,input_dim=29,activation='relu'),
    Dense(24,activation='relu'),
    Dropout(0.5),
    Dense(20,activation='relu'),
    Dense(24,activation='relu'),
    Dense(1,activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                 │ (None, 16)             │           480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 24)             │           408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 20)             │           500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 24)             │           504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            25 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,917 (7.49 KB)
#  Trainable params: 1,917 (7.49 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Model Training**

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(X_train,y_train,batch_size=15,epochs=5)
# Out:
# Epoch 1/5
# 15190/15190 ━━━━━━━━━━━━━━━━━━━━ 47s 3ms/step - accuracy: 0.9988 - loss: 0.0090
# Epoch 2/5
# 15190/15190 ━━━━━━━━━━━━━━━━━━━━ 59s 4ms/step - accuracy: 0.9993 - loss: 0.0040
# Epoch 3/5
# 15190/15190 ━━━━━━━━━━━━━━━━━━━━ 44s 3ms/step - accuracy: 0.9993 - loss: 0.0039
# Epoch 4/5
# 15190/15190 ━━━━━━━━━━━━━━━━━━━━ 81s 3ms/step - accuracy: 0.9993 - loss: 0.0037
# Epoch 5/5
# 15190/15190 ━━━━━━━━━━━━━━━━━━━━ 43s 3ms/step - accuracy: 0.9994 - loss: 0.0035

# %%
model.evaluate(X_test,y_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9992 - loss: 0.0031
# [0.0030744588002562523, 0.9992275834083557]

# %%
y_pred=model.predict(X_test)
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step

# %%
y_test=pd.DataFrame(y_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred.round())
sns.heatmap(cm,annot=True,fmt='d')
# Out:
# <Axes: >

# %%
y_pred=model.predict(X)
y_expected=pd.DataFrame(y)
# Out:
# 8901/8901 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_expected,y_pred.round())
sns.heatmap(cm,annot=True,cmap='plasma',fmt='d')
# Out:
# <Axes: >
